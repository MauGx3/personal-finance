# %%
from stockdex import Ticker
from datetime import datetime

ticker = Ticker(ticker="AAPL")

# Price data (use range and dataGranularity to make range and granularity more specific) from Yahoo Finance API
price = ticker.yahoo_api_price(range="1y", dataGranularity="1d")

# %%
price
# Out:
#               timestamp    volume       close        open        high  \
# 0   2024-03-28 13:30:00  65672700  171.479996  171.750000  172.229996
# 1   2024-04-01 13:30:00  46240500  170.029999  171.190002  171.250000
# 2   2024-04-02 13:30:00  49329500  168.839996  169.080002  169.339996
# 3   2024-04-03 13:30:00  47691700  169.649994  168.789993  170.679993
# 4   2024-04-04 13:30:00  53704400  168.820007  170.289993  171.919998
# ..                  ...       ...         ...         ...         ...
# 245 2025-03-21 13:30:00  94127800  218.270004  211.559998  218.839996
# 246 2025-03-24 13:30:00  44299500  220.729996  221.000000  221.479996
# 247 2025-03-25 13:30:00  34493600  223.750000  220.770004  224.100006
# 248 2025-03-26 13:30:00  34532700  221.529999  223.509995  225.020004
# 249 2025-03-27 20:00:01  36700954  223.850006  221.330002  224.990005
#
#             low currency timezone exchangeTimezoneName exchangeName  \
# 0    170.509995      USD      EDT     America/New_York          NMS
# 1    169.479996      USD      EDT     America/New_York          NMS
# 2    168.229996      USD      EDT     America/New_York          NMS
# 3    168.580002      USD      EDT     America/New_York          NMS
# 4    168.820007      USD      EDT     America/New_York          NMS
# ..          ...      ...      ...                  ...          ...
# 245  211.279999      USD      EDT     America/New_York          NMS
# 246  218.580002      USD      EDT     America/New_York          NMS
# 247  220.080002      USD      EDT     America/New_York          NMS
# 248  220.470001      USD      EDT     America/New_York          NMS
# 249  220.560104      USD      EDT     America/New_York          NMS
#
#     instrumentType
# 0           EQUITY
# 1           EQUITY
# 2           EQUITY
# 3           EQUITY
# 4           EQUITY
# ..             ...
# 245         EQUITY
# 246         EQUITY
# 247         EQUITY
# 248         EQUITY
# 249         EQUITY
#
# [250 rows x 11 columns]

# %%
# Complete historical data of the stock in certain categories from digrin website
dividend = ticker.digrin_dividend

# %%
dividend
# Out:
#    Ex-dividend date Payable date  \
# 0        2025-02-10   2025-02-13
# 1        2024-11-08   2024-11-14
# 2        2024-08-12   2024-08-15
# 3        2024-05-10   2024-05-16
# 4        2024-02-09   2024-02-15
# ..              ...          ...
# 81       1988-05-16   1988-06-15
# 82       1988-02-12   1988-03-15
# 83       1987-11-17   1987-12-15
# 84       1987-08-10   1987-09-15
# 85       1987-05-11   1987-06-15
#
#                              Dividend amount (change) Adjusted Price  \
# 0   0.2500 USD\n                       \n         ...     234.32 USD
# 1   0.2500 USD\n                       \n         ...     222.91 USD
# 2   0.2500 USD\n                       \n         ...     219.86 USD
# 3   0.2500 USD\n                       \n         ...     183.36 USD
# 4   0.2400 USD\n                       \n         ...     185.85 USD
# ..                                                ...            ...
# 81  0.0007 USD\n                       \n         ...       0.29 USD
# 82  0.0007 USD\n                       \n         ...       0.29 USD
# 83  0.0007 USD\n                       \n         ...       0.24 USD
# 84  0.0005 USD\n                       \n         ...       0.34 USD
# 85  0.0005 USD\n                       \n         ...       0.27 USD
#
#    Close Price
# 0   234.32 USD
# 1   222.91 USD
# 2   219.86 USD
# 3   183.36 USD
# 4   185.85 USD
# ..         ...
# 81    0.37 USD
# 82    0.37 USD
# 83    0.31 USD
# 84    0.43 USD
# 85    0.34 USD
#
# [86 rows x 5 columns]

# %%
# Summary including general financial information from Yahoo Finance website
summary = ticker.yahoo_web_summary

# %%
summary
# Out:
#                                            0
# marketState
# postMarketTime
# regularMarketPreviousClose           221.53
# regularMarketOpen                    221.33
# regularMarketDayRange       220.56 - 224.99
# fiftyTwoWeekRange           164.08 - 260.10
# regularMarketVolume              36,700,954
# averageVolume                    52,722,525
# marketCap                            3.363T
# trailingPE                             6.29
# targetMeanPrice                      252.59
# regularMarketPrice                    1.4600
# regularMarketChange                  -0.1000
# regularMarketChangePercent          (-6.41%)

# %%
from stockdex import Ticker

ticker = Ticker(ticker="AAPL")

# Summary including general financial information
summary = ticker.yahoo_web_summary

# Financial data as it is seen in the yahoo finance website
income_stmt = ticker.yahoo_web_income_stmt
balance_sheet = ticker.yahoo_web_balance_sheet
cash_flow = ticker.yahoo_web_cashflow

# Analysts and estimates
# analysis = ticker.yahoo_web_analysis

# Data about options
calls = ticker.yahoo_web_calls
puts = ticker.yahoo_web_puts

# Profile data
key_executives = ticker.yahoo_web_key_executives
description = ticker.yahoo_web_description
corporate_governance = ticker.yahoo_web_corporate_governance

# Data about shareholders
major_holders = ticker.yahoo_web_major_holders
top_institutional_holders = ticker.yahoo_web_top_institutional_holders
top_mutual_fund_holders = ticker.yahoo_web_top_mutual_fund_holders

# Statistics
valuation_measures = ticker.yahoo_web_valuation_measures
financial_highlights = ticker.yahoo_web_financial_highlights
trading_information = ticker.yahoo_web_trading_information

# %%
valuation_measures
# Out:
#                          Current 12/31/2024 9/30/2024 6/30/2024 3/31/2024  \
#
# Market Cap                3.33T      3.77T     3.52T     3.23T     2.65T
# Enterprise Value          3.37T      3.81T     3.56T     3.27T     2.68T
# Trailing P/E              35.16      41.19     35.46     32.76     26.67
# Forward P/E               30.21      33.67     30.67     28.65     26.32
# PEG Ratio (5yr expected)   2.06       2.29      2.24      2.23      2.11
# Price/Sales                8.57       9.87      9.38      8.62      6.99
# Price/Book                49.85      66.14     52.80     43.21     35.49
# Enterprise Value/Revenue   8.52       9.74      9.24      8.56      6.96
# Enterprise Value/EBITDA   24.54      28.28     26.35     24.57     20.10
#
#                          12/31/2023
#
# Market Cap                   2.99T
# Enterprise Value             3.06T
# Trailing P/E                 31.41
# Forward P/E                  29.15
# PEG Ratio (5yr expected)      2.31
# Price/Sales                   7.94
# Price/Book                   47.90
# Enterprise Value/Revenue      7.98
# Enterprise Value/EBITDA      23.66

# %%
top_institutional_holders
# Out:
#                             Holder     Shares   Date Reported    % Out  \
# 0              Vanguard Group Inc       1.4B    Dec 31, 2024    9.29%
# 1                  Blackrock Inc.      1.12B    Dec 31, 2024    7.48%
# 2        State Street Corporation     595.5M    Dec 31, 2024    3.96%
# 3                        FMR, LLC    341.64M    Dec 31, 2024    2.27%
# 4   Geode Capital Management, LLC    340.16M    Dec 31, 2024    2.26%
# 5         Berkshire Hathaway, Inc       300M    Dec 31, 2024    2.00%
# 6                  Morgan Stanley    238.26M    Dec 31, 2024    1.59%
# 7   Price (T.Rowe) Associates Inc    220.11M    Dec 31, 2024    1.47%
# 8                     NORGES BANK    187.16M    Dec 31, 2024    1.25%
# 9             JPMORGAN CHASE & CO    183.01M    Dec 31, 2024    1.22%
#
#                Value
# 0   312,446,595,380
# 1   251,477,038,183
# 2   133,303,015,976
# 3    76,476,334,115
# 4    76,145,917,851
# 5    67,155,001,831
# 6    53,335,429,417
# 7    49,271,073,053
# 8    41,895,803,406
# 9    40,966,375,718
