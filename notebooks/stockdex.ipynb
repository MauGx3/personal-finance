# %%
from stockdex import Ticker
from datetime import datetime

ticker = Ticker(ticker="AAPL")

# Price data (use range and dataGranularity to make range and granularity more specific) from Yahoo Finance API
price = ticker.yahoo_api_price(range="1y", dataGranularity="1d")

# %%
price
# Out:
#               timestamp    volume       close        open        high  \
# 0   2024-09-04 13:30:00  43840200  220.850006  221.660004  221.779999
# 1   2024-09-05 13:30:00  36615400  222.380005  221.630005  225.479996
# 2   2024-09-06 13:30:00  48423000  220.820007  223.949997  225.240005
# 3   2024-09-09 13:30:00  67180000  220.910004  220.820007  221.270004
# 4   2024-09-10 13:30:00  51591000  220.110001  218.919998  221.479996
# ..                  ...       ...         ...         ...         ...
# 246 2025-08-28 13:30:00  38074700  232.559998  230.820007  233.410004
# 247 2025-08-29 13:30:00  39418400  232.139999  232.509995  233.380005
# 248 2025-09-02 13:30:00  44075600  229.720001  229.250000  230.850006
# 249 2025-09-03 13:30:00  66302400  238.470001  237.210007  238.850006
# 250 2025-09-04 16:05:41  19821674  237.300003  238.449997  239.893204
#
#             low currency timezone exchangeTimezoneName exchangeName  \
# 0    217.479996      USD      EDT     America/New_York          NMS
# 1    221.520004      USD      EDT     America/New_York          NMS
# 2    219.770004      USD      EDT     America/New_York          NMS
# 3    216.710007      USD      EDT     America/New_York          NMS
# 4    216.729996      USD      EDT     America/New_York          NMS
# ..          ...      ...      ...                  ...          ...
# 246  229.339996      USD      EDT     America/New_York          NMS
# 247  231.369995      USD      EDT     America/New_York          NMS
# 248  226.970001      USD      EDT     America/New_York          NMS
# 249  234.360001      USD      EDT     America/New_York          NMS
# 250  236.740005      USD      EDT     America/New_York          NMS
#
#     instrumentType
# 0           EQUITY
# 1           EQUITY
# 2           EQUITY
# 3           EQUITY
# 4           EQUITY
# ..             ...
# 246         EQUITY
# 247         EQUITY
# 248         EQUITY
# 249         EQUITY
# 250         EQUITY
#
# [251 rows x 11 columns]

# %%
# Complete historical data of the stock in certain categories from digrin website
dividend = ticker.digrin_dividend

# %%
dividend
# Out:
#    Ex-dividend date Payable date  \
# 0        2025-08-11   2025-08-14
# 1        2025-05-12   2025-05-15
# 2        2025-02-10   2025-02-13
# 3        2024-11-08   2024-11-14
# 4        2024-08-12   2024-08-15
# ..              ...          ...
# 83       1988-05-16   1988-06-15
# 84       1988-02-12   1988-03-15
# 85       1987-11-17   1987-12-15
# 86       1987-08-10   1987-09-15
# 87       1987-05-11   1987-06-15
#
#                              Dividend amount (change) Adjusted Price  \
# 0   0.2600 USD\n                       \n         ...     202.38 USD
# 1   0.2600 USD\n                       \n         ...     205.35 USD
# 2   0.2500 USD\n                       \n         ...     234.32 USD
# 3   0.2500 USD\n                       \n         ...     222.91 USD
# 4   0.2500 USD\n                       \n         ...     219.86 USD
# ..                                                ...            ...
# 83  0.0007 USD\n                       \n         ...       0.29 USD
# 84  0.0007 USD\n                       \n         ...       0.29 USD
# 85  0.0007 USD\n                       \n         ...       0.24 USD
# 86  0.0005 USD\n                       \n         ...       0.34 USD
# 87  0.0005 USD\n                       \n         ...       0.27 USD
#
#    Close Price
# 0   202.38 USD
# 1   205.35 USD
# 2   234.32 USD
# 3   222.91 USD
# 4   219.86 USD
# ..         ...
# 83    0.37 USD
# 84    0.37 USD
# 85    0.31 USD
# 86    0.43 USD
# 87    0.34 USD
#
# [88 rows x 5 columns]

# %%
# Summary including general financial information from Yahoo Finance website
summary = ticker.yahoo_web_summary

# %%
summary
# Out:
#                                            0
# marketState
# regularMarketTime
# regularMarketPreviousClose           238.47
# regularMarketOpen                    238.45
# regularMarketDayRange       236.77 - 239.89
# fiftyTwoWeekRange           169.21 - 260.10
# regularMarketVolume              19,823,447
# averageVolume                    54,570,856
# marketCap                            3.522T
# trailingPE                             6.58
# targetMeanPrice                      235.53
# regularMarketPrice                    218.74
# regularMarketChange                   -10.59
# regularMarketChangePercent          (-4.62%)

# %%
from stockdex import Ticker

ticker = Ticker(ticker="AAPL")

# Summary including general financial information
summary = ticker.yahoo_web_summary

# Financial data as it is seen in the yahoo finance website
income_stmt = ticker.yahoo_web_income_stmt
balance_sheet = ticker.yahoo_web_balance_sheet
cash_flow = ticker.yahoo_web_cashflow

# Analysts and estimates
# analysis = ticker.yahoo_web_analysis

# Data about options
calls = ticker.yahoo_web_calls
puts = ticker.yahoo_web_puts

# Profile data
key_executives = ticker.yahoo_web_key_executives
description = ticker.yahoo_web_description
corporate_governance = ticker.yahoo_web_corporate_governance

# Data about shareholders
major_holders = ticker.yahoo_web_major_holders
top_institutional_holders = ticker.yahoo_web_top_institutional_holders
top_mutual_fund_holders = ticker.yahoo_web_top_mutual_fund_holders

# Statistics
valuation_measures = ticker.yahoo_web_valuation_measures
financial_highlights = ticker.yahoo_web_financial_highlights
trading_information = ticker.yahoo_web_trading_information

# %%
valuation_measures
# Out:
#                          Current 6/30/2025 3/31/2025 12/31/2024 9/30/2024  \
#
# Market Cap                3.41T     3.05T     3.32T      3.77T     3.52T
# Enterprise Value          3.46T     3.10T     3.36T      3.81T     3.56T
# Trailing P/E              36.19     31.96     35.26      41.19     35.46
# Forward P/E               30.03     25.71     30.30      33.67     30.67
# PEG Ratio (5yr expected)   2.16      1.87      2.06       2.29      2.24
# Price/Sales                8.81      7.79      8.59       9.87      9.38
# Price/Book                53.76     45.63     49.71      66.14     52.80
# Enterprise Value/Revenue   8.77      7.74      8.49       9.74      9.24
# Enterprise Value/EBITDA   25.30     22.31     24.47      28.28     26.35
#
#                          6/30/2024
#
# Market Cap                  3.23T
# Enterprise Value            3.27T
# Trailing P/E                32.76
# Forward P/E                 28.65
# PEG Ratio (5yr expected)     2.23
# Price/Sales                  8.62
# Price/Book                  43.21
# Enterprise Value/Revenue     8.56
# Enterprise Value/EBITDA     24.57

# %%
top_institutional_holders
# Out:
#                                               Holder     Shares  \
# 0   VANGUARD INDEX FUNDS-Vanguard Total Stock Mar...   480.28M
# 1      VANGUARD INDEX FUNDS-Vanguard 500 Index Fund    423.95M
# 2   Fidelity Concord Street Trust-Fidelity 500 In...   189.25M
# 3                            SPDR S&P 500 ETF TRUST    181.13M
# 4            iShares Trust-iShares Core S&P 500 ETF    176.81M
# 5   VANGUARD INDEX FUNDS-Vanguard Growth Index Fund    147.87M
# 6                       Invesco QQQ Trust, Series 1    125.26M
# 7   VANGUARD INSTITUTIONAL INDEX FUNDS-Vanguard I...    91.54M
# 8   VANGUARD WORLD FUND-Vanguard Information Tech...    74.02M
# 9     iShares Trust-iShares Russell 1000 Growth ETF     55.75M
#
#     Date Reported    % Out              Value
# 0   Jun 30, 2025    3.24%    113,995,340,075
# 1   Jun 30, 2025    2.86%    100,624,755,823
# 2   Jun 30, 2025    1.28%     44,917,401,829
# 3   Jun 30, 2025    1.22%     42,990,723,835
# 4   Jun 30, 2025    1.19%     41,965,723,087
# 5   Jun 30, 2025    1.00%     35,097,610,931
# 6   Jun 30, 2025    0.84%     29,730,232,009
# 7   Jun 30, 2025    0.62%     21,727,822,039
# 8   May 31, 2025    0.50%     17,568,378,771
# 9   Jun 30, 2025    0.38%     13,232,571,157
